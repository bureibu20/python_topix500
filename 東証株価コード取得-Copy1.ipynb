# %%
import requests

url = "https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls"
r = requests.get(url)
with open('data_j.xls', 'wb') as output:
    output.write(r.content)

# %%
import pandas as pd

#東京証券取引所から銘柄一覧データを取得する
#https://www.jpx.co.jp/markets/statistics-equities/misc/01.html

stocklist = pd.read_excel("./data_j.xls")
stocklist
# Out:
#             日付   コード                                   銘柄名  \
# 0     20220131  1301                                    極洋
# 1     20220131  1305                         ダイワ上場投信－トピックス
# 2     20220131  1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信
# 3     20220131  1308                     上場インデックスファンドＴＯＰＩＸ
# 4     20220131  1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信
# ...        ...   ...                                   ...
# 4169  20220131  9993                                  ヤマザワ
# 4170  20220131  9994                                   やまや
# 4171  20220131  9995                                 グローセル
# 4172  20220131  9996                                 サトー商会
# 4173  20220131  9997                                  ベルーナ
#
#                  市場・商品区分 33業種コード  33業種区分 17業種コード  17業種区分 規模コード           規模区分
# 0             市場第一部（内国株）      50  水産・農林業       1     食品      7  TOPIX Small 2
# 1                ETF・ETN       -       -       -       -     -              -
# ...

# %%
stock_class = stocklist["市場・商品区分"]
stock_class
# Out:
# 0               市場第一部（内国株）
# 1                  ETF・ETN
# 2                  ETF・ETN
# 3                  ETF・ETN
# 4                  ETF・ETN
#                ...
# 4169            市場第一部（内国株）
# 4170            市場第一部（内国株）
# 4171            市場第一部（内国株）
# 4172    JASDAQ(スタンダード・内国株）
# 4173            市場第一部（内国株）
# Name: 市場・商品区分, Length: 4174, dtype: object

# %%
stock_class.unique()
# Out:
# array(['市場第一部（内国株）', 'ETF・ETN', 'JASDAQ(スタンダード・内国株）', 'JASDAQ(グロース・内国株）',
#        'マザーズ（内国株）', 'PRO Market', '市場第二部（内国株）', '市場第一部（外国株）',
#        'REIT・ベンチャーファンド・カントリーファンド・インフラファンド', 'JASDAQ(スタンダード・外国株）',
#        'マザーズ（外国株）', '出資証券', '市場第二部（外国株）'], dtype=object)

# %%
stock_class = stocklist[(stocklist["市場・商品区分"]=="市場第一部（内国株）")|
                 (["市場・商品区分"]=="JASDAQ(スタンダード・内国株）") |
                 (["市場・商品区分"]=="JASDAQ(グロース・内国株）") |
                 (["市場・商品区分"]=="マザーズ（内国株）") |
                 (["市場・商品区分"]=="市場第二部（内国株）") |
                 (["市場・商品区分"]=="JASDAQ(スタンダード・内国株）")]
    

stock_class
# Out:
#             日付   コード     銘柄名     市場・商品区分 33業種コード  33業種区分 17業種コード  17業種区分  \
# 0     20220131  1301      極洋  市場第一部（内国株）      50  水産・農林業       1     食品
# 19    20220131  1332    日本水産  市場第一部（内国株）      50  水産・農林業       1     食品
# 20    20220131  1333  マルハニチロ  市場第一部（内国株）      50  水産・農林業       1     食品
# 26    20220131  1352    ホウスイ  市場第一部（内国株）    6050     卸売業      13  商社・卸売
# 37    20220131  1375  雪国まいたけ  市場第一部（内国株）      50  水産・農林業       1     食品
# ...        ...   ...     ...         ...     ...     ...     ...     ...
# 4168  20220131  9991    ジェコス  市場第一部（内国株）    6050     卸売業      13  商社・卸売
# 4169  20220131  9993    ヤマザワ  市場第一部（内国株）    6100     小売業      14     小売
# 4170  20220131  9994     やまや  市場第一部（内国株）    6100     小売業      14     小売
# 4171  20220131  9995   グローセル  市場第一部（内国株）    6050     卸売業      13  商社・卸売
# 4173  20220131  9997    ベルーナ  市場第一部（内国株）    6100     小売業      14     小売
#
#      規模コード           規模区分
# 0        7  TOPIX Small 2
# 19       4   TOPIX Mid400
# ...

# %%
stock_class.to_excel("test.xlsx")

# %%
stocklist.loc[stocklist["市場・商品区分"]=="市場第一部（内国株）",
              ["コード","銘柄名","33業種コード","33業種区分","規模コード","規模区分"]
             ]
# Out:
#        コード     銘柄名 33業種コード  33業種区分 規模コード           規模区分
# 0     1301      極洋      50  水産・農林業     7  TOPIX Small 2
# 19    1332    日本水産      50  水産・農林業     4   TOPIX Mid400
# 20    1333  マルハニチロ      50  水産・農林業     4   TOPIX Mid400
# 26    1352    ホウスイ    6050     卸売業     7  TOPIX Small 2
# 37    1375  雪国まいたけ      50  水産・農林業     6  TOPIX Small 1
# ...    ...     ...     ...     ...   ...            ...
# 4168  9991    ジェコス    6050     卸売業     7  TOPIX Small 2
# 4169  9993    ヤマザワ    6100     小売業     7  TOPIX Small 2
# 4170  9994     やまや    6100     小売業     7  TOPIX Small 2
# 4171  9995   グローセル    6050     卸売業     7  TOPIX Small 2
# 4173  9997    ベルーナ    6100     小売業     6  TOPIX Small 1
#
# [2184 rows x 6 columns]
